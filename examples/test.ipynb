# %%
import polars as pl

from sylphy.sequence_encoder import create_encoder

# %%
df = pl.DataFrame({"sequence": ["MKTAYIAKQR", "GAVLIMPFWK", "PEPTIDE"]})

encoder = create_encoder(
    "one_hot",  # or: ordinal, kmers, frequency, physicochemical, fft
    dataset=df,
    sequence_column="sequence",
)
encoder.run_process()

# %%
encoder.coded_dataset
# Out:
# shape: (3, 20_481)
# ┌─────┬─────┬─────┬─────┬───┬─────────┬─────────┬─────────┬────────────┐
# │ p_0 ┆ p_1 ┆ p_2 ┆ p_3 ┆ … ┆ p_20477 ┆ p_20478 ┆ p_20479 ┆ sequence   │
# │ --- ┆ --- ┆ --- ┆ --- ┆   ┆ ---     ┆ ---     ┆ ---     ┆ ---        │
# │ u8  ┆ u8  ┆ u8  ┆ u8  ┆   ┆ u8      ┆ u8      ┆ u8      ┆ str        │
# ╞═════╪═════╪═════╪═════╪═══╪═════════╪═════════╪═════════╪════════════╡
# │ 0   ┆ 0   ┆ 0   ┆ 0   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ MKTAYIAKQR │
# │ 0   ┆ 0   ┆ 0   ┆ 0   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ GAVLIMPFWK │
# │ 0   ┆ 0   ┆ 0   ┆ 0   ┆ … ┆ 0       ┆ 0       ┆ 0       ┆ PEPTIDE    │
# └─────┴─────┴─────┴─────┴───┴─────────┴─────────┴─────────┴────────────┘
